# %%
# !mkdir food_dataset
# !./google-cloud-sdk/bin/gsutil -m cp -r "gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead" ./food_dataset
# !./google-cloud-sdk/bin/gsutil -m cp -r "gs://nutrition5k_dataset/nutrition5k_dataset/metadata" ./food_dataset
# !./google-cloud-sdk/bin/gsutil -m cp -r "gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids" ./food_dataset
# Out:
# mkdir: cannot create directory ‘food_dataset’: File exists
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556572657/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556572657/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556572657/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556573514/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556573514/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575014/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575014/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575083/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556573514/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575014/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575083/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575124/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575083/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575124/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575124/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575273/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575273/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575273/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575327/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575327/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575446/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575327/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575386/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575386/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575386/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575499/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575558/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575558/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575499/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575499/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575446/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575558/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575446/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575700/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575700/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853154/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1556575700/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853154/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853229/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853154/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853229/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853229/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853314/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861605/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853314/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861605/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861697/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853314/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853429/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861697/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861697/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861795/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861216/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853429/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861795/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861837/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861216/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861795/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861837/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862345/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861837/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862345/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862345/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862783/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862783/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862738/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861216/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862829/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862738/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862783/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557853429/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862829/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862829/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557861605/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862696/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863056/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863012/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863012/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863104/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863012/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863056/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863056/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862696/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863104/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862696/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557862738/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863104/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863170/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863170/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557863170/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936555/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936555/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936599/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936555/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936599/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936645/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936599/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936645/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557936645/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937037/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937037/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937037/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937079/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937079/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937079/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937157/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937157/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937335/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937157/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937335/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937335/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937427/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937427/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937427/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937574/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937615/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937615/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937574/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937574/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937615/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937715/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937715/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937758/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937758/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937758/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1557937715/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026623/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026623/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026623/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026684/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026684/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026714/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026714/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026756/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026756/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026684/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026714/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558026756/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027001/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027001/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027001/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027057/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027057/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027164/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027243/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027164/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027164/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027243/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027057/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028007/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028007/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028007/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028057/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028057/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558027243/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028057/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028142/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028142/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028194/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028194/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028142/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028194/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028492/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028492/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028492/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028606/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028606/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028606/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028690/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028690/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028772/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028690/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028772/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558028772/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029148/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029148/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029148/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029230/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029230/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029278/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029278/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029278/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029324/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029230/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029324/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029324/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029518/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029518/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029686/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029518/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029686/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029686/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029842/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029842/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029842/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030182/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029923/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029923/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030182/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030289/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030289/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030289/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558029923/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030383/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030383/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030383/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030435/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030182/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030435/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030435/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030724/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030724/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030724/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030832/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030832/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030910/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030832/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030910/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030971/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030910/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030971/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558030971/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031019/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031019/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031019/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031133/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031133/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031237/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031237/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031237/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031302/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031133/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031302/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031302/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031351/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031351/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031351/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031394/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031394/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031526/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031526/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031394/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031526/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031566/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031566/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031628/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031628/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031628/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031675/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031675/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031566/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109864/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558031675/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558032156/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109864/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558032156/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109864/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558032156/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109907/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109945/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109986/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109986/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109907/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109945/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109907/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109945/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558109986/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110245/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110245/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110245/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110297/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110297/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110297/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110335/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110335/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110335/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110385/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110385/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110385/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110436/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110436/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110436/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110478/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110478/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558110478/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113154/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113204/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113154/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113204/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113154/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113204/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113255/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113255/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113255/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113304/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113304/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113304/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113430/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113430/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113430/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113477/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113477/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113477/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113941/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113941/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114086/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558113941/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114086/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114145/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114284/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114145/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114209/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114145/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114209/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114209/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114284/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114284/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114441/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114441/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114441/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114086/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114484/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114484/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114484/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114523/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114523/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114523/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114569/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114609/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114569/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114609/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114875/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114569/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114609/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114875/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114875/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114937/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114937/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115011/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558114937/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115011/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115011/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115047/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115047/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115047/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115169/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115169/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115169/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115241/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115241/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115241/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115282/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115282/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115320/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115282/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115320/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115364/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115320/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115364/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115364/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115448/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115448/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115448/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115512/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115512/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115512/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115601/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115601/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115601/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115641/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115641/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115764/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115825/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115764/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115641/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115764/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115825/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115825/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115867/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115915/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115867/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115915/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115867/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115960/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115915/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115960/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558115960/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116001/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116001/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116090/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116001/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116090/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116090/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116146/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116146/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116201/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116201/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116260/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116146/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116260/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116260/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116201/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116298/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116298/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116298/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116399/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116399/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116399/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116436/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116436/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116436/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116486/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116486/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116547/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116547/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116486/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558122740/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558372433/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558122583/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558122583/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558122583/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558116547/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558372525/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558372433/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558122740/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558122740/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558372433/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558372525/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1558372650/depth_color.png...
# ...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574444158/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574443421/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574444158/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574455444/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574444158/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574455444/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574455444/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574455483/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574455483/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574702427/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574455483/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574702473/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574702473/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574702473/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574702427/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711418/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574702427/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711418/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711418/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711451/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711451/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711451/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711517/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711517/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711517/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711589/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711589/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574720429/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574720429/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574711589/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574728191/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574720429/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574728191/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574728229/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574728191/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574728229/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1574728229/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307466/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307819/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307466/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307466/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307819/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307819/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307845/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575308389/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307845/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575393132/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575308389/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575308389/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575393132/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575404926/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575307845/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575404926/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575404926/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575393132/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575407477/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575478635/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575478663/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575407477/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575478635/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575407477/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575478663/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575478663/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575478635/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575481406/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575481406/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575481406/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575481443/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575481443/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575481443/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575653017/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575653017/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575653017/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575664962/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575664962/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575664962/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575923584/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575923584/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575923584/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575923893/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575923893/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997210/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575923893/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997210/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997210/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997241/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997241/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997241/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997268/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575998399/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997268/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575997268/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575998399/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576100046/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575998399/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575999037/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575999037/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576100046/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576100046/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171118/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1575999037/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171118/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171157/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171118/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171157/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171157/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171204/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171204/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171204/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171237/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171237/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576171237/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576183111/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576183111/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576183111/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258613/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258613/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258657/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258657/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258613/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258657/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258685/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576259732/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258685/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576258685/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576259732/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576259776/depth_color.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576259732/rgb.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576259776/depth_raw.png...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/imagery/realsense_overhead/dish_1576259776/rgb.png...
# | [10.5k/10.5k files][  3.0 GiB/  3.0 GiB] 100% Done   3.2 MiB/s ETA 00:00:00
# Operation completed over 10.5k objects/3.0 GiB.
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/metadata/dish_metadata_cafe2.csv...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/metadata/dish_metadata_cafe1.csv...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/metadata/ingredients_metadata.csv...
# / [3/3 files][  2.2 MiB/  2.2 MiB] 100% Done
# Operation completed over 3 objects/2.2 MiB.
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/dish_ids_all.txt...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/README...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/dish_ids_cafe2.txt...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/dish_ids_cafe1.txt...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/splits/depth_test_ids.txt...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/splits/depth_train_ids.txt...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/splits/rgb_test_ids.txt...
# Copying gs://nutrition5k_dataset/nutrition5k_dataset/dish_ids/splits/rgb_train_ids.txt...
# / [8/8 files][282.4 KiB/282.4 KiB] 100% Done
# Operation completed over 8 objects/282.4 KiB.

# %%
# prompt: create a dataloader for the nutrition5k_dataset. Filenames are located inside the food_dataset/dish_ids/splits/rgb_train_ids.txt for training and  food_dataset/dish_ids/splits/rgb_test_ids.txt for testing.
# for each filename inside the text, the file is located in:  food_dataset/realsense_overhead/<FILENAME>/rgb.png. 

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os
import csv

class Nutrition5kDataset(Dataset):
    def __init__(self, data_dir, split='train', transform=None):
        self.data_dir = data_dir
        self.split = split
        self.transform = transform

        if split == 'train':
            split_file = os.path.join(data_dir, 'dish_ids', 'splits', 'rgb_train_ids.txt')
        elif split == 'test':
            split_file = os.path.join(data_dir, 'dish_ids', 'splits', 'rgb_test_ids.txt')
        else:
            raise ValueError("Invalid split. Choose 'train' or 'test'.")

        with open(split_file, 'r') as f:
            self.image_ids = [line.strip() for line in f]
            self.image_ids = [image_id for image_id in self.image_ids if os.path.exists(os.path.join(data_dir, 'realsense_overhead', image_id, 'rgb.png'))]
        
        #self.image_ids = os.listdir(os.path.join(data_dir, 'realsense_overhead'))
        #self.image_ids = [image_id for image_id in self.image_ids if os.path.exists(os.path.join(data_dir, 'realsense_overhead', image_id, 'rgb.png'))]
        print(len(self.image_ids))

    def __len__(self):
        return len(self.image_ids)

    def get_csv_line(self, image_id):
      csv_files = [
          "./food_dataset/metadata/dish_metadata_cafe1.csv",
          #"./food_dataset/metadata/dish_metadata_cafe2.csv"
      ]

      for csv_file in csv_files:
          if os.path.exists(csv_file):
              with open(csv_file, 'r', encoding='utf-8') as file:
                  reader = csv.reader(file) 
                  for row in reader:
                      if row and row[0] == image_id:  
                          return row  
      return None  

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        image_path = os.path.join(self.data_dir, 'realsense_overhead', image_id, 'rgb.png')
        
        try:
          image = Image.open(image_path).convert('RGB')
        except FileNotFoundError:
          print(f"Warning: Image file not found at {image_path}. Skipping.")
          # Return a placeholder or handle the error as needed
          return torch.zeros(size=((3, 224, 224))), None

        if self.transform:
            image = self.transform(image)
        
        target = ",".join(self.get_csv_line(image_id))
        if target is None:
            return torch.zeros(size=((3, 224, 224))), None
        return image, target
      
norm_image = lambda x: x*2-1.
# Example Usage
data_dir = './food_dataset'
transform_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Lambda(norm_image),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=20),
    # transforms.ColorJitter(brightness=0.001)
])
transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Lambda(norm_image),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomRotation(degrees=10),
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1)
])

train_dataset = Nutrition5kDataset(data_dir, split='train', transform=transform_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2) # Adjust num_workers as needed


test_dataset = Nutrition5kDataset(data_dir, split='test', transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2) # Adjust num_workers as needed
# Out:
# 2755
# 507

# %%
print(train_dataset[0][0].max())

print(0*2-1, 0.5*2-1, 1*2-1)
# Out:
# tensor(1.)
# -1 0.0 1

# %%
# prompt: create a function to visualize samples from the train_dataset

import matplotlib.pyplot as plt
import numpy as np

def visualize_samples(dataset, num_samples=5):
    """Visualizes samples from the dataset."""
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 5))
    for i in range(num_samples):
        sample, target = dataset[i]
        if sample is not None:  # Check for potential None values
          # Convert tensor to numpy array and handle different image formats
          if isinstance(sample, torch.Tensor):
              image = sample.permute(1, 2, 0).numpy()
          elif isinstance(sample, np.ndarray):
              image = sample
          else: # Assuming it's PIL image
              image = np.array(sample)

          # Normalize pixel values to the range 0-1 for display
          # image = (image - image.min()) / (image.max() - image.min())
          image = (image+1.)/2

          axes[i].imshow(image)
          axes[i].set_title(target[0])
          axes[i].axis('off')
    plt.show()

# Visualize samples from train_dataset
visualize_samples(train_dataset)

# %%
import torch
import torch.nn as nn
from torchvision import models

class CustomModel(nn.Module):
    def __init__(self, num_classes=5):
        super(CustomModel, self).__init__()
        # Load a pre-trained MobileNetV2 model (small model)
        self.model = models.mobilenet_v2( pretrained=True)

        # Freeze pre-trained layers
        for param in self.model.parameters():
           param.requires_grad = False

        # Modify the final classification layer
        num_ftrs = self.model.classifier[1].in_features
        self.model.classifier[1] = nn.Linear(num_ftrs, 512)
        self.out_linear = nn.Linear(512, num_classes)

    def forward(self, x):
        c = self.model(x)
        c = torch.nn.functional.relu6(c)
        # return torch.nn.functional.relu(self.out_linear(c))
        return torch.exp(self.out_linear(c))

# Example usage:
model = CustomModel()
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
a = torch.normal(10, 2, size=(4,5))
print(a)
mean = torch.mean(a, axis=0)
print(mean)
std = torch.std(a, axis=0)
print(std)
norm_a = (a-mean)/std

print('norm_a', norm_a)

from_norm_a = norm_a*std+mean
print('from_norm_a', from_norm_a)
# Out:
# tensor([[12.4782, 10.9815, 11.7613, 10.7192, 10.6614],
#         [ 3.1691, 10.4469,  9.5568,  8.0705,  9.0575],
#         [10.6962,  8.8069,  7.4965,  8.4256,  8.3006],
#         [ 6.7578, 10.5105, 11.6694, 10.4683,  6.6713]])
# tensor([ 8.2753, 10.1865, 10.1210,  9.4209,  8.6727])
# tensor([4.1594, 0.9501, 2.0244, 1.3659, 1.6580])
# norm_a tensor([[ 1.0105,  0.8368,  0.8103,  0.9505,  1.1994],
#         [-1.2276,  0.2741, -0.2787, -0.9887,  0.2321],
#         [ 0.5820, -1.4520, -1.2964, -0.7287, -0.2244],
#         [-0.3648,  0.3411,  0.7649,  0.7668, -1.2071]])
# from_norm_a tensor([[12.4782, 10.9815, 11.7613, 10.7192, 10.6614],
#         [ 3.1691, 10.4469,  9.5568,  8.0705,  9.0575],
#         [10.6962,  8.8069,  7.4965,  8.4256,  8.3006],
#         [ 6.7578, 10.5105, 11.6694, 10.4683,  6.6713]])

# %%
import torch
torch.nn.functional.relu
# Out:
# <function torch.nn.functional.relu(input: torch.Tensor, inplace: bool = False) -> torch.Tensor>

# %%
def evaluate():
  model.eval()
  threshold_a = 0.5
  threshold_a = 0.7
  correct_predictions = 0
  total_predictions = 0
  with torch.no_grad():
      for images, labels_raw in tqdm(test_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Evaluation"):
          if images is None:
              continue

          images = images.to(device)
          labels = convert_labels(labels_raw)
          outputs = model(images)
          _, predicted = torch.max(outputs, 1)
          total_predictions += labels.size(0)
          correct_predictions += (predicted == labels).sum().item()

  accuracy = 100 * correct_predictions / total_predictions
  print(f"Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {accuracy:.2f}%")

# %%
# carregar pesos no modelo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CustomModel().to(device)
model.load_state_dict(torch.load("./weights_scaling_log_mean_image/best_model.pth"))
# Out:
# <All keys matched successfully>

# %%
import torch
import torch.optim as optim
from tqdm import tqdm

def save_checkpoint(model, test_loss, save_dir="./weights_scaling_log_mean_image"):
    os.makedirs(save_dir, exist_ok=True)
    
    # Save last model weights (always overwrite)
    last_model_path = os.path.join(save_dir, "last_model.pth")
    torch.save(model.state_dict(), last_model_path)
    
    # Track best loss in a file to persist between runs
    best_loss_path = os.path.join(save_dir, "best_loss.txt")
    best_model_path = os.path.join(save_dir, "best_model.pth")
    
    # Initialize best loss
    best_loss = float('inf')
    if os.path.exists(best_loss_path):
        with open(best_loss_path, 'r') as f:
            best_loss = float(f.read())
    
    # Save new best model if current loss is better
    if test_loss < best_loss:
        print(f"New best model found! Loss improved from {best_loss:.4f} to {test_loss:.4f}")
        
        # Save best model weights
        torch.save(model.state_dict(), best_model_path)
        
        # Update best loss record
        with open(best_loss_path, 'w') as f:
            f.write(str(test_loss))

# %%
def loss_fn(y1, y):
    return torch.nn.functional.mse_loss(torch.sigmoid(y1), y)

def mag_loss(pred, labels):
    batch = pred.shape[0]
    probs = torch.sigmoid(pred)
    diff = probs - labels
    labels = labels.reshape(batch, 555, 2)
    diff = diff.reshape(batch, 555, 2)
    diff = diff.sum(-1)
    diff = torch.where(labels[..., 0]==1., diff*4, diff)
    mse = torch.mean(diff**2)
    return mse

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.00025) # Example optimizer

# %%
mean_scaling = torch.tensor([254.93, 218.01, 12.71, 19.33, 18.10]).to(device)
std_scaling = torch.tensor([220.97, 163.06, 13.41, 22.29, 20.22]).to(device)

def convert_labels(labels):
    # Placeholder: Implement your label conversion logic here.
    # This will take the output from get_csv_line() and convert it to numerical labels.
    # Example: Convert string labels to numerical IDs.
    targets = torch.zeros(len(labels), 5).to(device)
    for i, label in enumerate(labels):
        label = label.split(",")
        # ... your conversion logic ...
        #print(label)
        dish_id, total_calories, total_mass, total_fat, total_carb, total_protein = label[:6]
        ingrs = label[6:]
        for j in range(len(ingrs)//7):
          k = j*7
          #print(ingrs[k:k+7])
          ingr_id = int(ingrs[k].replace("ingr_", "")) - 1
          ingr_name = ingrs[k+1]
          ingr_mass = ingrs[k+2]

          # relative_mass = float(ingr_mass) / float(total_mass)

        #   targets[i, ingr_id*2] = 1.
        #   targets[i, ingr_id*2+1] = relative_mass

          targets[i, 0] = float(total_calories)
          targets[i, 1] = float(total_mass)
          targets[i, 2] = float(total_fat)
          targets[i, 3] = float(total_carb)
          targets[i, 4] = float(total_protein)

    return targets/mean_scaling

# %%
def validate():
    model.eval()
    running_loss = .0
    for images, labels_raw in tqdm(test_loader, desc=f"Evaluating"):
      
        if images is None or not torch.any(images):
            continue
        images = images.to(device)
        labels = convert_labels(labels_raw)
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_loss+=loss.item()
    validation_loss = running_loss/len(test_loader)
    print('\nValidation loss:', validation_loss)
    return validation_loss

# %%
num_epochs = 10  # Set the number of epochs

def train(num_epochs):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, labels_raw in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training"):
            # Skip if images is None (due to missing image files)
            if images is None or not torch.any(images):
                continue

            images = images.to(device)
            labels = convert_labels(labels_raw)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)
        print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}")

        validation_loss = validate()
        save_checkpoint(model, validation_loss)


    print("Training finished.")

# %%
train(num_epochs)
# Out:
# Epoch 1/10 - Training: 100%|██████████| 87/87 [02:03<00:00,  1.42s/it]
# Epoch [1/10], Training Loss: 0.8153
# Evaluating: 100%|██████████| 16/16 [00:18<00:00,  1.17s/it]
# Validation loss: 0.49523478746414185
# New best model found! Loss improved from inf to 0.4952
# Epoch 2/10 - Training: 100%|██████████| 87/87 [01:50<00:00,  1.27s/it]
# Epoch [2/10], Training Loss: 0.6613
# Evaluating: 100%|██████████| 16/16 [00:17<00:00,  1.09s/it]
# Validation loss: 0.4348892290145159
# New best model found! Loss improved from 0.4952 to 0.4349
# Epoch 3/10 - Training: 100%|██████████| 87/87 [01:45<00:00,  1.21s/it]
# Epoch [3/10], Training Loss: 0.5986
# Evaluating: 100%|██████████| 16/16 [00:16<00:00,  1.01s/it]
# Validation loss: 0.423894913867116
# New best model found! Loss improved from 0.4349 to 0.4239
# Epoch 4/10 - Training: 100%|██████████| 87/87 [01:48<00:00,  1.24s/it]
# Epoch [4/10], Training Loss: 0.6124
# Evaluating: 100%|██████████| 16/16 [00:18<00:00,  1.17s/it]
# Validation loss: 0.45214894972741604
# Epoch 5/10 - Training: 100%|██████████| 87/87 [01:51<00:00,  1.28s/it]
# Epoch [5/10], Training Loss: 0.6005
# Evaluating: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Validation loss: 0.44629526510834694
# Epoch 6/10 - Training: 100%|██████████| 87/87 [01:54<00:00,  1.32s/it]
# Epoch [6/10], Training Loss: 0.5651
# Evaluating: 100%|██████████| 16/16 [00:18<00:00,  1.13s/it]
# Validation loss: 0.46302784979343414
# Epoch 7/10 - Training: 100%|██████████| 87/87 [01:45<00:00,  1.21s/it]
# Epoch [7/10], Training Loss: 0.5730
# Evaluating: 100%|██████████| 16/16 [00:15<00:00,  1.00it/s]
# Validation loss: 0.4215013515204191
# New best model found! Loss improved from 0.4239 to 0.4215
# Epoch 8/10 - Training: 100%|██████████| 87/87 [01:44<00:00,  1.21s/it]
# Epoch [8/10], Training Loss: 0.5556
# Evaluating: 100%|██████████| 16/16 [00:18<00:00,  1.14s/it]
# Validation loss: 0.39890389144420624
# New best model found! Loss improved from 0.4215 to 0.3989
# Epoch 9/10 - Training: 100%|██████████| 87/87 [01:58<00:00,  1.36s/it]
# Epoch [9/10], Training Loss: 0.5562
# Evaluating: 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
# Validation loss: 0.41788878105580807
# Epoch 10/10 - Training: 100%|██████████| 87/87 [01:55<00:00,  1.33s/it]
# Epoch [10/10], Training Loss: 0.5484
# Evaluating: 100%|██████████| 16/16 [00:19<00:00,  1.19s/it]
# Validation loss: 0.3791889250278473
# New best model found! Loss improved from 0.3989 to 0.3792
# Training finished.

# %%
for param in model.model.parameters():
    param.requires_grad = True
train(num_epochs)
# Out:
# Epoch 1/10 - Training: 100%|██████████| 87/87 [03:43<00:00,  2.57s/it]
# Epoch [1/10], Training Loss: 0.5992
# Evaluating: 100%|██████████| 16/16 [00:15<00:00,  1.06it/s]
# Validation loss: 0.44788347743451595
# Epoch 2/10 - Training: 100%|██████████| 87/87 [03:17<00:00,  2.27s/it]
# Epoch [2/10], Training Loss: 0.5380
# Evaluating: 100%|██████████| 16/16 [00:16<00:00,  1.01s/it]
# Validation loss: 0.4711149726063013
# Epoch 3/10 - Training: 100%|██████████| 87/87 [03:32<00:00,  2.44s/it]
# Epoch [3/10], Training Loss: 0.4812
# Evaluating: 100%|██████████| 16/16 [00:13<00:00,  1.20it/s]
# Validation loss: 0.4115178659558296
# Epoch 4/10 - Training: 100%|██████████| 87/87 [03:46<00:00,  2.61s/it]
# Epoch [4/10], Training Loss: 0.4622
# Evaluating: 100%|██████████| 16/16 [00:17<00:00,  1.08s/it]
# Validation loss: 0.3499696971848607
# New best model found! Loss improved from 0.3792 to 0.3500
# Epoch 5/10 - Training:  45%|████▍     | 39/87 [02:15<03:02,  3.79s/it]

# %%
def evaluate():
    accuracy = 0
    n = 0
    current_acc = 0
    for images, labels_raw in tqdm(test_loader, desc=f"Evaluating"):
      
        if images is None or not torch.any(images):
            continue
        labels = convert_labels(labels_raw)
        threshold = 0.7

        model.eval()
        outputs = model(images)
        batch_size = outputs.shape[0]
        outputs = torch.sigmoid(outputs.reshape(batch_size, 555, 2))
        labels = labels.reshape(batch_size, 555, 2)
        probs = (outputs[..., 0] >= threshold).int()
        correct_preds = probs==(labels[..., 0].int())
        correct_preds = correct_preds.float().mean()
        current_acc = correct_preds
        accuracy += correct_preds
        n+=1

        #### ingredient regression accuracy
        ## absolute difference
        pred_pct = outputs[..., 1]
        true_pct = labels[..., 1]
        abs_diff = torch.abs(pred_pct-true_pct).mean()
        
        print(f"Batch acc: {correct_preds}\t ingr_diff: {abs_diff}")

    print(f"Accuracy: {(accuracy/n).detach().cpu().numpy()}")

# %%
device="cpu"
def evaluate_nutrients():
    accuracy = 0
    n = 0
    model.eval()
    running_diff = torch.tensor([0., 0, 0, 0, 0], requires_grad=False).to(device)

    for images, labels_raw in tqdm(test_loader, desc=f"Evaluating"):
      
        if images is None or not torch.any(images):
            continue
        images = images.to(device)
        labels = convert_labels(labels_raw)
        with torch.no_grad():
            outputs = model(images)
        images.detach()
        del images
        n+=1
        avg_diff = (outputs - labels).mean(0)
        
        avg_diff = avg_diff*mean_scaling
        avg_diff = torch.abs(avg_diff)
        running_diff += avg_diff
        
        # total_calories, total_mass, total_fat, total_carb, total_protein, 
        #print("Current diff\tCal:{:.1f}\tMass:{:.1f}\tFat:{:.1f}\tCarb:{:.1f}\tProt:{:.1f}".format(*avg_diff))
    diff = running_diff/n
    print("\n", "-"*50)
    print("Resultado - Erro médio absoluto:")
    print(f"Calorias:\t{diff[0]:.2f}")
    print(f"Massa:\t\t{diff[1]:.2f}")
    print(f"Lipídios:\t{diff[2]:.2f}")
    print(f"Carboidratos:\t{diff[3]:.2f}")
    print(f"Proteínas:\t{diff[4]:.2f}")
    return diff

# %%
evaluate_nutrients()
# Out:
# Evaluating: 100%|██████████| 16/16 [00:15<00:00,  1.06it/s]
#  --------------------------------------------------
# Resultado - Erro médio absoluto:
# Calorias:	11.24
# Massa:		25.22
# Lipídios:	0.74
# Carboidratos:	1.76
# Proteínas:	2.52
# tensor([11.2396, 25.2194,  0.7434,  1.7587,  2.5240])

# %%
evaluate_nutrients()
# Out:
# Evaluating:   6%|▋         | 1/16 [00:01<00:28,  1.90s/it]
# Current diff\Cal:33.2	Mass:15.0	Fat:-0.7	Carb:0.8	Prot:-3.4
# Current diff\Cal:30.9	Mass:36.0	Fat:-2.0	Carb:-0.6	Prot:-2.3
# Evaluating:  19%|█▉        | 3/16 [00:03<00:13,  1.01s/it]
# Current diff\Cal:61.8	Mass:32.7	Fat:1.1	Carb:0.7	Prot:-0.6
# Current diff\Cal:45.1	Mass:28.0	Fat:-1.3	Carb:1.1	Prot:-0.2
# Evaluating:  31%|███▏      | 5/16 [00:04<00:09,  1.17it/s]
# Current diff\Cal:31.7	Mass:19.3	Fat:-0.2	Carb:-2.3	Prot:-2.9
# Current diff\Cal:63.5	Mass:52.2	Fat:0.4	Carb:0.7	Prot:3.0
# Evaluating:  44%|████▍     | 7/16 [00:06<00:07,  1.26it/s]
# Current diff\Cal:70.8	Mass:51.7	Fat:1.1	Carb:1.7	Prot:0.7
# Current diff\Cal:17.1	Mass:32.1	Fat:-3.2	Carb:-2.1	Prot:-0.2
# Evaluating:  56%|█████▋    | 9/16 [00:07<00:05,  1.26it/s]
# Current diff\Cal:35.8	Mass:-6.9	Fat:0.2	Carb:-0.0	Prot:-3.4
# Current diff\Cal:34.5	Mass:29.9	Fat:-1.7	Carb:-2.0	Prot:0.3
# Evaluating:  69%|██████▉   | 11/16 [00:09<00:03,  1.31it/s]
# Current diff\Cal:25.3	Mass:16.7	Fat:-3.2	Carb:1.0	Prot:-2.0
# Current diff\Cal:53.9	Mass:26.3	Fat:-1.4	Carb:2.4	Prot:-0.0
# Evaluating:  81%|████████▏ | 13/16 [00:10<00:02,  1.38it/s]
# Current diff\Cal:24.7	Mass:5.6	Fat:-0.5	Carb:-2.0	Prot:-0.6
# Current diff\Cal:17.0	Mass:22.3	Fat:-2.3	Carb:0.7	Prot:-2.7
# Evaluating: 100%|██████████| 16/16 [00:11<00:00,  1.36it/s]
# Current diff\Cal:31.6	Mass:27.1	Fat:-2.0	Carb:-0.3	Prot:-0.6
# Current diff\Cal:15.7	Mass:23.4	Fat:-1.9	Carb:2.4	Prot:-5.7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 evaluate_nutrients()
#
# Cell In[36], line 22, in evaluate_nutrients()
#      20     # total_calories, total_mass, total_fat, total_carb, total_protein,
#      21     print("Current diff\Cal:{:.1f}\tMass:{:.1f}\tFat:{:.1f}\tCarb:{:.1f}\tProt:{:.1f}".format(*avg_diff))
# ---> 22 return total_loss/n
#
# NameError: name 'total_loss' is not defined

# %%
import torch
x = torch.normal(10, 1, size=(2,5)).to('cuda') / torch.tensor([10, 10, 5, 5, 2])
x
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 import torch
# ----> 2 x = torch.normal(10, 1, size=(2,5)).to('cuda') / torch.tensor([10, 10, 5, 5, 2])
#       3 x
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %%
a = torch.tensor([0.3])
a.int()
# Out:
# tensor([0], dtype=torch.int32)

# %%
help(torch.gather)
# Out:
# Help on built-in function gather in module torch:
#
# gather(...)
#     gather(input, dim, index, *, sparse_grad=False, out=None) -> Tensor
#
#     Gathers values along an axis specified by `dim`.
#
#     For a 3-D tensor the output is specified by::
#
#         out[i][j][k] = input[index[i][j][k]][j][k]  # if dim == 0
#         out[i][j][k] = input[i][index[i][j][k]][k]  # if dim == 1
#         out[i][j][k] = input[i][j][index[i][j][k]]  # if dim == 2
#
#     :attr:`input` and :attr:`index` must have the same number of dimensions.
#     It is also required that ``index.size(d) <= input.size(d)`` for all
#     dimensions ``d != dim``.  :attr:`out` will have the same shape as :attr:`index`.
#     Note that ``input`` and ``index`` do not broadcast against each other.
#
#     Args:
#         input (Tensor): the source tensor
#         dim (int): the axis along which to index
#         index (LongTensor): the indices of elements to gather
#
#     Keyword arguments:
#         sparse_grad (bool, optional): If ``True``, gradient w.r.t. :attr:`input` will be a sparse tensor.
#         out (Tensor, optional): the destination tensor
#
#     Example::
#
#         >>> t = torch.tensor([[1, 2], [3, 4]])
#         >>> torch.gather(t, 1, torch.tensor([[0, 0], [1, 0]]))
#         tensor([[ 1,  1],
#                 [ 4,  3]])

# %%
num_epochs = 10  # Set the number of epochs

for epoch in range(num_epochs):
  model.train()
  running_loss = 0.0

  for images, labels_raw in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training"):
      # Skip if images is None (due to missing image files)
      if images is None or not torch.any(images):
          continue

      images = images.to(device)
      labels = convert_labels(labels_raw)

      optimizer.zero_grad()
      outputs = model(images)
      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()
      running_loss += loss.item()

  epoch_loss = running_loss / len(train_loader)
  print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}")

  # Evaluation loop


print("Training finished.")
# Out:
# Epoch 1/10 - Training: 100%|██████████| 87/87 [00:51<00:00,  1.69it/s]
# Epoch [1/10], Training Loss: 0.0393
# Epoch 2/10 - Training: 100%|██████████| 87/87 [00:48<00:00,  1.81it/s]
# Epoch [2/10], Training Loss: 0.0373
# Epoch 3/10 - Training: 100%|██████████| 87/87 [00:48<00:00,  1.81it/s]
# Epoch [3/10], Training Loss: 0.0332
# Epoch 4/10 - Training: 100%|██████████| 87/87 [00:46<00:00,  1.87it/s]
# Epoch [4/10], Training Loss: 0.0337
# Epoch 5/10 - Training: 100%|██████████| 87/87 [00:47<00:00,  1.83it/s]
# Epoch [5/10], Training Loss: 0.0313
# Epoch 6/10 - Training: 100%|██████████| 87/87 [00:47<00:00,  1.84it/s]
# Epoch [6/10], Training Loss: 0.0296
# Epoch 7/10 - Training: 100%|██████████| 87/87 [00:46<00:00,  1.88it/s]
# Epoch [7/10], Training Loss: 0.0295
# Epoch 8/10 - Training: 100%|██████████| 87/87 [00:45<00:00,  1.89it/s]
# Epoch [8/10], Training Loss: 0.0263
# Epoch 9/10 - Training: 100%|██████████| 87/87 [00:48<00:00,  1.81it/s]
# Epoch [9/10], Training Loss: 0.0253
# Epoch 10/10 - Training: 100%|██████████| 87/87 [00:47<00:00,  1.81it/s]
# Epoch [10/10], Training Loss: 0.0281
# Training finished.

# %%
len(train_dataset)
# Out:
# 330

# %%
model.load_state_dict()

# %%
torch.save(model.state_dict(), 'model_weights_cal_regression.pth')

# %%
images, labels_raw = next(iter(test_loader))
images = images.to(device)
labels = convert_labels(labels_raw)
outputs = model(images)
import numpy as np
a = labels[2].detach().cpu().numpy()
b = torch.sigmoid(outputs[2]).detach().cpu().numpy()
print(np.argmax(a))
print(np.argmax(b))
print(list(a))
print("=============")
print(list(b))
print('.')
k = np.argmax(a)
print(a[k-2:k+2])
print(b[k-2:k+2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 images, labels_raw = next(iter(test_loader))
#       2 images = images.to(device)
#       3 labels = convert_labels(labels_raw)
#
# NameError: name 'test_loader' is not defined

# %%
torch.nn.functional.mse_loss(torch.sigmoid(outputs[:1]), labels[:1])
# Out:
# tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
probs = torch.sigmoid(outputs[:1])
diff = probs - labels[:1]
diff = torch.where(labels==1., diff*10, diff)
mse = torch.mean(diff**2)
print(mse)
# Out:
# tensor(0.0566, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
def mag_loss(pred, labels):
    probs = torch.sigmoid(pred)
    diff = probs - labels
    diff = torch.where(labels==1., diff*10, diff)
    mse = torch.mean(diff**2)
    return mse

# %%
with open("food_dataset/metadata/ingredients_metadata.csv") as file:
    class_names = [line.split(',')[0] for line in file][1:]
print("number os classes:", len(class_names))
# Out:
# number os classes: 555

# %%
# carregar pesos no modelo
model.load_state_dict(torch.load("./weights/best_model.pth"))
# Out:
# <All keys matched successfully>

# %%
def inference(img_path):
    model.eval()
    img = Image.open(img_path).convert('RGB')
    img = transform_train(img).unsqueeze(0).to(device)
    output = model(img)*mean_scaling
    print(output)
# dish_1558375833,317.032013,92.000000,25.116001,3.864000,17.756001
inference("./food_dataset/realsense_overhead/dish_1551314290/rgb.png")
# 240.425751,194.000000,10.293161,10.249402,25.324493
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 8
#       6     print(output)
#       7 # dish_1558375833,317.032013,92.000000,25.116001,3.864000,17.756001
# ----> 8 inference("./food_dataset/realsense_overhead/dish_1551314290/rgb.png")
#       9 # 240.425751,194.000000,10.293161,10.249402,25.324493
#
# Cell In[34], line 3, in inference(img_path)
#       1 def inference(img_path):
#       2     model.eval()
# ----> 3     img = Image.open(img_path).convert('RGB')
#       4     img = transform_train(img).unsqueeze(0).to(device)
#       5     output = model(img)*mean_scaling
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/PIL/Image.py:3465, in open(fp, mode, formats)
#    3462     filename = os.fspath(fp)
#    3464 if filename:
# -> 3465     fp = builtins.open(filename, "rb")
#    3466     exclusive_fp = True
#    3467 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './food_dataset/realsense_overhead/dish_1551314290/rgb.png'

# %%
model.load_state_dict(torch.load("./weights_scaling_log_mean/best_model.pth"))
# Out:
# <All keys matched successfully>

# %%
def visualize_from_test_dataset(num_samples=10):
    model.eval()
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 5))
    for i in range(num_samples):
        sample, target = test_dataset[i]
        if sample is not None:  # Check for potential None values
          # Convert tensor to numpy array and handle different image formats
          if isinstance(sample, torch.Tensor):
              image = sample.permute(1, 2, 0).numpy()
          elif isinstance(sample, np.ndarray):
              image = sample
          else: # Assuming it's PIL image
              image = np.array(sample)

          # Normalize pixel values to the range 0-1 for display
          image = (image - image.min()) / (image.max() - image.min())
          target = target.split(',')
          img_id = target[0]
          cal = float(target[1])
          mass = float(target[2])
          fat = float(target[3])
          carb = float(target[4])
          prot = float(target[5])

          output = model(sample.unsqueeze(0))*mean_scaling
          output = output.detach()

          axes[i].imshow(image)
          axes[i].set_title(img_id)
          axes[i].axis('off')
          print(f"{img_id}{'True': >8}{'Pred': >8}")
          print(f"Cal{cal:20.1f}{output[0,0]:8.1f}")
          print(f"Mass{mass:19.1f}{output[0,1]:8.1f}")
          print(f"Fat{fat:20.1f}{output[0,2]:8.1f}")
          print(f"Carb{carb:19.1f}{output[0,3]:8.1f}")
          print(f"Prot{prot:19.1f}{output[0,4]:8.1f}")
          print("-"*50)

    plt.show()

# Visualize samples from train_dataset
visualize_from_test_dataset(5)
# Out:
# dish_1565035746    True    Pred
# Cal                43.1   163.8
# Mass              149.0   195.6
# Fat                 0.4     6.9
# Carb                9.0    11.7
# Prot                2.4    16.0
# --------------------------------------------------
# dish_1558639818    True    Pred
# Cal                20.1    56.0
# Mass               59.0   100.2
# Fat                 0.1     1.6
# Carb                4.7    12.9
# Prot                0.5     2.5
# --------------------------------------------------
# dish_1558549605    True    Pred
# Cal                97.5   104.0
# Mass               75.0   131.0
# Fat                 0.2     3.8
# Carb               21.0     9.7
# Prot                2.0     7.6
# --------------------------------------------------
# dish_1561663580    True    Pred
# Cal               432.1   405.5
# Mass              307.0   289.7
# Fat                 9.8    18.5
# Carb               31.3    21.6
# Prot               51.4    45.7
# --------------------------------------------------
# dish_1565898402    True    Pred
# Cal               384.8   377.7
# Mass              229.0   290.4
# Fat                19.5    21.6
# Carb                9.5    20.3
# Prot               39.4    34.7
# --------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def visualize_nutrition_distributions(data_list):
    """
    Visualizes nutritional distributions with multiple plots:
    - Histograms with KDE and statistics
    - Boxplots
    - Correlation heatmap
    """
    # Extract numerical values from the data
    nutrients = {
        'Total Calories': [],
        'Total Mass': [],
        'Total Fat': [],
        'Total Carb': [],
        'Total Protein': []
    }
    
    for item in data_list:
        nutrients['Total Calories'].append(float(item[1]))
        nutrients['Total Mass'].append(float(item[2]))
        nutrients['Total Fat'].append(float(item[3]))
        nutrients['Total Carb'].append(float(item[4]))
        nutrients['Total Protein'].append(float(item[5]))
    
    # Create main distribution plots
    fig, axs = plt.subplots(5, 2, figsize=(16, 24))
    plt.subplots_adjust(hspace=0.4)
    fig.suptitle('Nutritional Distributions Analysis', fontsize=20, y=0.99)
    
    for idx, (nutrient, values) in enumerate(nutrients.items()):
        # Convert to numpy array for easier calculations
        arr = np.array(values)
        
        # Histogram with statistics
        axs[idx, 0].hist(arr, bins=30, color='skyblue', edgecolor='black', density=True)
        axs[idx, 0].set_title(f'{nutrient} Distribution', fontsize=12)
        axs[idx, 0].set_xlabel(nutrient)
        axs[idx, 0].set_ylabel('Density')
        
        # Add statistical annotations
        stats_text = (f'Mean: {arr.mean():.2f}\n'
                      f'Median: {np.median(arr):.2f}\n'
                      f'Std Dev: {arr.std():.2f}\n'
                      f'Min: {arr.min():.2f}\n'
                      f'Max: {arr.max():.2f}')
        axs[idx, 0].text(0.98, 0.85, stats_text, transform=axs[idx, 0].transAxes,
                        ha='right', va='top', bbox=dict(facecolor='white', alpha=0.8))
        
        # Boxplot
        axs[idx, 1].boxplot(arr, vert=False, patch_artist=True,
                           boxprops=dict(facecolor='lightgreen'))
        axs[idx, 1].set_title(f'{nutrient} Boxplot', fontsize=12)
        axs[idx, 1].set_xlabel(nutrient)
        axs[idx, 1].set_yticks([])
    
    # Create correlation matrix heatmap
    df = pd.DataFrame({
        'Calories': nutrients['Total Calories'],
        'Mass': nutrients['Total Mass'],
        'Fat': nutrients['Total Fat'],
        'Carbs': nutrients['Total Carb'],
        'Protein': nutrients['Total Protein']
    })
    
    corr_matrix = df.corr()
    
    fig2, ax = plt.subplots(figsize=(10, 8))
    cax = ax.matshow(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1)
    fig2.colorbar(cax)
    
    # Set labels and annotations
    ax.set_xticks(np.arange(len(corr_matrix.columns)))
    ax.set_yticks(np.arange(len(corr_matrix.columns)))
    ax.set_xticklabels(corr_matrix.columns, rotation=45)
    ax.set_yticklabels(corr_matrix.columns)
    ax.set_title('Nutrient Correlation Matrix', pad=20)
    
    # Add correlation values
    for (i, j), val in np.ndenumerate(corr_matrix):
        ax.text(j, i, f'{val:.2f}', ha='center', va='center', 
                color='white' if abs(val) < 0.5 else 'black')
    
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def visualize_nutrition_distributions_seaborn(data_list):
    """
    Visualizes nutritional distributions using Seaborn:
    - Histograms with KDE for each nutrient
    - Boxplots for each nutrient
    - Pairplot for relationships between nutrients
    - Correlation heatmap
    """
    # Convert data to a pandas DataFrame
    df = pd.DataFrame(data_list, columns=["img_id", "total_calories", "total_mass", 
                                          "total_fat", "total_carb", "total_protein"])
    
    # Convert numerical columns to float
    numerical_cols = ["total_calories", "total_mass", "total_fat", "total_carb", "total_protein"]
    df[numerical_cols] = df[numerical_cols].astype(float)
    
    # Set Seaborn style
    sns.set(style="whitegrid", palette="pastel")
    
    # Create a figure for histograms and boxplots
    fig, axes = plt.subplots(5, 2, figsize=(16, 20))
    fig.suptitle("Nutritional Distributions Analysis", fontsize=20, y=1.02)
    
    # Plot histograms and boxplots for each nutrient
    for i, col in enumerate(numerical_cols):
        # Histogram with KDE
        sns.histplot(df[col], kde=True, ax=axes[i, 0], color="skyblue", bins=30)
        axes[i, 0].set_title(f"{col.replace('_', ' ').title()} Distribution", fontsize=14)
        axes[i, 0].set_xlabel(col.replace('_', ' ').title())
        axes[i, 0].set_ylabel("Density")
        
        # Boxplot
        sns.boxplot(x=df[col], ax=axes[i, 1], color="lightgreen")
        axes[i, 1].set_title(f"{col.replace('_', ' ').title()} Boxplot", fontsize=14)
        axes[i, 1].set_xlabel(col.replace('_', ' ').title())
    
    plt.tight_layout()
    plt.show()
    
    # Pairplot to show relationships between nutrients
    print("\nPairplot of Nutritional Relationships:")
    sns.pairplot(df[numerical_cols], diag_kind="kde", corner=True, plot_kws={"s": 10})
    plt.suptitle("Pairplot of Nutritional Relationships", y=1.02)
    plt.show()
    
    # Correlation heatmap
    print("\nCorrelation Heatmap:")
    plt.figure(figsize=(10, 8))
    corr = df[numerical_cols].corr()
    sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", vmin=-1, vmax=1, 
                linewidths=0.5, cbar_kws={"shrink": 0.8})
    plt.title("Nutrient Correlation Heatmap", fontsize=16, pad=20)
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %%
visualize_nutrition_distributions(i[1].split(',')[:6] for i in train_dataset)

# %%
visualize_nutrition_distributions_seaborn(i[1].split(',')[:6] for i in test_dataset)
# Out:
# Pairplot of Nutritional Relationships:
# Correlation Heatmap:

# %%
["img001", "525.5", "350.0", "32.1", "45.6", "24.8", "p"][:6]
# Out:
# ['img001', '525.5', '350.0', '32.1', '45.6', '24.8']
